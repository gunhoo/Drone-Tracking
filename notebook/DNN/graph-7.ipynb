# %%
import matplotlib.pyplot as plt
# %matplotlib inline

oneX = []
oneY = []
meanX = [1,10,20,30,40,50]
meanY = [1,13.2794,26.2,33.1529,39.8,41.4618]


for i in range(0,34):
    oneX.append(0)
    oneY.append(0)
    
for i in range(0,34):
    oneX.append(1)
    oneY.append(1)
    
for i in range(0,34):
    oneX.append(10)
oneY.extend([10.5,19,18.7,10,10.4,13.6,10,10,10,10,10.8,16.7,10.2,13.5,10.8,26,16.4,18.2,18.2,17.6,12,10,11.3,10.4,10,11.6,18.4,17.2,10,10,10,10,10,10])

for i in range(0,34):
    oneX.append(20)
oneY.extend([74.4,50.4,48.8,0,49.6,19.5,19.6,19.8,19.3,19.7,20,20,21.6,64,55.2,34.4,19.7,19.8,19.8,20,20,19.7,20,20,0,72,0,45.6,0,0,19.8,19.2,19.4,19.5])

for i in range(1, 35):
    oneX.append(30)
oneY.extend([40,29,33.2,37.4,39.3,39.4,38.8,33,38.1,34.6,28.5,39.4,38.8,29.5,25,29.4,26.9,35.8,37.2,40,35.8,24.7,22,23.1,22,39,40,40,34.5,26.5,22.4,32.8,33,38.1])

for i in range(1, 35):
    oneX.append(40)
oneY.extend([40,40,40,40,37.5,36.2,39.9,39.6,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40])

for i in range(1, 35):
    oneX.append(50)
oneY.extend([49.4,47.6,49.1,50,49.4,47,47.6,48.2,47.3,37.9,19.8,21.7,21.7,19.4,24.5,45.5,48.2,45.5,45.5,37.7,40.8,47.3,47.6,47.3,47,44,34.5,45.8,48.5,44,44.3,36.7,39.5,39.4])


fig= plt.figure(figsize=(5,7.5))
axes= fig.add_subplot(111)

#axes.set_xticks([0,50, 20, 10, 1])


axes.plot(oneX, oneY,'x')
plt.xlabel('Actual Distance (m)')
plt.ylabel('Calculated Distance (m)')
axes.plot(meanX, meanY)
axes.set_yticks([0,10,20,30,40,50,60,70])
#plt.show()

plt.savefig('graph7-04percentage.png',dpi=900)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

oneX = []
oneY = []
meanX = [1,10,20,30,40,50]
meanY = [1,12.9412,15.2941,33.5294,40,44.7059]

for i in range(0,34):
    oneX.append(0)
    oneY.append(0)
    
for i in range(0,34):
    oneX.append(1)
    oneY.append(1)
    
for i in range(0,34):
    oneX.append(40)
    oneY.append(40)

for i in range(1,35):
    oneX.append(10)
oneY.extend([10,20,20,10,10,10,10,10,10,10,10,20,10,10,10,20,20,20,20,20,10,10,10,10,10,10,20,20,10,10,10,10,10,10])

for i in range(1,35):
    oneX.append(20)
oneY.extend([0,20,20,0])
for i in range(0,9):
    oneY.append(20)
oneY.append(0)
for i in range(0,10):
    oneY.append(20)
oneY.extend([0,0,0,20,0,0,20,20,20,20])

for i in range(0,34):
    oneX.append(30)
for i in range(0,9):
    oneY.append(40)
oneY.extend([20,20,40,40,40,20,20,20,40,40,40,40,20,20,20,20,40,40,40,40,20,20,40,40,40])

for i in range(0,34):
    oneX.append(50)
for i in range(0,10):
    oneY.append(50)
oneY.extend([20,20,20,20,20])
for i in range(0,11):
    oneY.append(50)
oneY.append(20)
for i in range(0,7):
    oneY.append(50)

fig= plt.figure(figsize=(5,7.5))
axes= fig.add_subplot(111)

#axes.set_xticks([0,50, 20, 10, 1])


axes.plot(oneX, oneY,'x')
plt.xlabel('Actual Distance (m)')
plt.ylabel('Calculated Distance (m)')
axes.plot(meanX, meanY)
axes.set_yticks([0,10,20,30,40,50,60,70])
#plt.show()

plt.savefig('graph7-04output.png',dpi=900)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

oneX = []
oneY = []
meanX = [1,10,20,30,40,50]
meanY = [1,12.5,30,33.125,40,44.375]


for i in range(0,8):
    oneX.append(0)
    oneY.append(0)
for i in range(0,8):
    oneX.append(1)
    oneY.append(1)
for i in range(0,8):
    oneX.append(40)
    oneY.append(40)

for i in range(0,8):
    oneX.append(10)
oneY.extend([15,10,12.5,12.5,20,10,15,10])

for i in range(1,9):
    oneX.append(20)
oneY.extend([60,20,20,20,20,20,0,60])

for i in range(1,9):
    oneX.append(30)
oneY.extend([40,40,30,30,35,25,35,30])

for i in range(1,9):
    oneX.append(50)
oneY.extend([50,50,35,27.5,50,50,42.5,50])

    

fig= plt.figure(figsize=(5,7.5))
axes= fig.add_subplot(111)


axes.plot(oneX, oneY,'x')
plt.xlabel('Actual Distance (m)')
plt.ylabel('Calculated Distance (m)')
axes.plot(meanX, meanY)
axes.set_yticks([0,10,20,30,40,50,60,70])
#plt.show()

plt.savefig('graph7-1.png',dpi=900)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

oneX = []
oneY = []
meanX = [1,10,20,30,40,50]
meanY = [1,13.125,30,33.125,40,44.375]


for i in range(0,4):
    oneX.append(0)
    oneY.append(0)
for i in range(0,4):
    oneX.append(1)
    oneY.append(1)
for i in range(0,4):
    oneX.append(40)
    oneY.append(40)

for i in range(0,4):
    oneX.append(10)
oneY.extend([12.5,12.5,15,12.5])

for i in range(1,5):
    oneX.append(20)
oneY.extend([40,30,20,30])

for i in range(1,5):
    oneX.append(30)
oneY.extend([40,30,30,32.5])

for i in range(1,5):
    oneX.append(50)
oneY.extend([50,31.25,50,46.25])

    

fig= plt.figure(figsize=(5,7.5))
axes= fig.add_subplot(111)


axes.plot(oneX, oneY,'x')
plt.xlabel('Actual Distance (m)')
plt.ylabel('Calculated Distance (m)')
axes.plot(meanX, meanY)
axes.set_yticks([0,10,20,30,40,50,60,70])
#plt.show()

plt.savefig('graph7-2.png',dpi=900)
