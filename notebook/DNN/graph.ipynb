# %%
import matplotlib.pyplot as plt
# %matplotlib inline

oneX = []
oneY = []
meanX = [1,10,20,50]
meanY = [1,10,27.0588,49.1176]


for i in range(0,33):
    oneX.append(0)
    oneY.append(-2)
for i in range(34,66):
    oneX.append(50)
    oneY.append(50)
oneX.append(50)
oneY.append(20)
for i in range(1,8):
    oneX.append(20)
    oneY.append(50)
for i in range(1,26):
    oneX.append(20)
    oneY.append(20)
for i in range(1, 10):
    oneX.append(10)
    oneY.append(20)
for i in range(1,22):
    oneX.append(10)
    oneY.append(10)
for i in range(1,2):
    oneX.append(10)
    oneY.append(1)
for i in range(1,34):
    oneX.append(1)
    oneY.append(1)
    

fig= plt.figure(figsize=(4,4))
axes= fig.add_subplot(111)

#axes.set_xticks([0,50, 20, 10, 1])


axes.plot(oneX, oneY,'x')
plt.xlabel('Actual Distance (m)')
plt.ylabel('Calculated Distance (m)')
axes.plot(meanX, meanY)
axes.set_yticks([0,5,10,15,20,25,30,35,40,45,50,-5])
#plt.show()

plt.savefig('graph04.png',dpi=900)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

oneX = []
oneY = []
meanX = [1,10,20,50]
meanY = [1,11.2813,17.125,49.0625]


for i in range(1,8):
    oneX.append(0)
    oneY.append(-2)
for i in range(1,7):
    oneX.append(50)
    oneY.append(50)
oneX.append(50)
oneY.append(42.5)

for i in range(1,3):
    oneX.append(20)
    oneY.append(20)
for i in range(1,2):
    oneX.append(20)
    oneY.append(17.5)
for i in range(1, 2):
    oneX.append(20)
    oneY.append(15)
oneX.append(20)
oneY.append(10)

for i in range(1,3):
    oneX.append(10)
    oneY.append(10)
for i in range(1,2):
    oneX.append(10)
    oneY.append(15)
oneX.append(10)
oneY.append(7.5)
oneX.append(10)
oneY.append(12.5)
oneX.append(10)
oneY.append(10.25)
    
for i in range(1,8):
    oneX.append(1)
    oneY.append(1)
    

fig= plt.figure(figsize=(4,4))
axes= fig.add_subplot(111)

#axes.set_xticks([0,50, 20, 10, 1])


axes.plot(oneX, oneY,'x')
plt.xlabel('Actual Distance (m)')
plt.ylabel('Calculated Distance (m)')
axes.plot(meanX, meanY)
axes.set_yticks([0,5,10,15,20,25,30,35,40,45,50,-5])
#plt.show()

plt.savefig('graph1.png',dpi=900)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

oneX = []
oneY = []
meanX = [1,10,20,50]
meanY = [1,11.2,18.125,50]


for i in range(1,4):
    oneX.append(0)
    oneY.append(-2)

for i in range(1,4):
    oneX.append(50)
    oneY.append(50)

for i in range(1,2):
    oneX.append(20)
    oneY.append(20)
oneX.append(20)
oneY.append(17.5)
oneX.append(20)
oneY.append(15)

for i in range(1,2):
    oneX.append(10)
    oneY.append(10)
oneX.append(10)
oneY.append(15)
oneX.append(10)
oneY.append(12.5)
    
for i in range(1,4):
    oneX.append(1)
    oneY.append(1)
    

fig= plt.figure(figsize=(4,4))
axes= fig.add_subplot(111)

#axes.set_xticks([0,50, 20, 10, 1])


axes.plot(oneX, oneY,'x')
plt.xlabel('Actual Distance (m)')
plt.ylabel('Calculated Distance (m)')
axes.plot(meanX, meanY)
axes.set_yticks([0,5,10,15,20,25,30,35,40,45,50,-5])
#plt.show()

plt.savefig('graph2.png',dpi=900)
